# %% [markdown]
# # Python Insights - Analisando Dados com Python
#
# ### Case - Cancelamento de Clientes
#
# Você foi contratado por uma empresa com mais de 800 mil clientes para um projeto de Dados. Recentemente a empresa percebeu que da sua base total de clientes, a maioria são clientes inativos, ou seja, que já cancelaram o serviço.
#
# Precisando melhorar seus resultados ela quer conseguir entender os principais motivos desses cancelamentos e quais as ações mais eficientes para reduzir esse número.
#
# Base de dados e arquivos: https://drive.google.com/drive/folders/1uDesZePdkhiraJmiyeZ-w5tfc8XsNYFZ?usp=drive_link

# %%
import pandas as pd

tabela = pd.read_csv("cancelamentos.csv")
tabela = tabela.drop("CustomerID", axis=1)
display(tabela)
# Out:
#         idade    sexo  tempo_como_cliente  frequencia_uso  \
# 0        30.0  Female                39.0            14.0
# 1        65.0  Female                49.0             1.0
# 2        55.0  Female                14.0             4.0
# 3        58.0    Male                38.0            21.0
# 4        23.0    Male                32.0            20.0
# ...       ...     ...                 ...             ...
# 881661   42.0    Male                54.0            15.0
# 881662   25.0  Female                 8.0            13.0
# 881663   26.0    Male                35.0            27.0
# 881664   28.0    Male                55.0            14.0
# 881665   31.0    Male                48.0            20.0
#
#         ligacoes_callcenter  dias_atraso assinatura duracao_contrato  \
# 0                       5.0         18.0   Standard           Annual
# 1                      10.0          8.0      Basic          Monthly
# 2                       6.0         18.0      Basic        Quarterly
# 3                       7.0          7.0   Standard          Monthly
# 4                       5.0          8.0      Basic          Monthly
# ...                     ...          ...        ...              ...
# 881661                  1.0          3.0    Premium           Annual
# 881662                  1.0         20.0    Premium           Annual
# 881663                  1.0          5.0   Standard        Quarterly
# 881664                  2.0          0.0   Standard        Quarterly
# 881665                  1.0         14.0    Premium        Quarterly
#
#         total_gasto  meses_ultima_interacao  cancelou
# 0            932.00                    17.0       1.0
# 1            557.00                     6.0       1.0
# 2            185.00                     3.0       1.0
# 3            396.00                    29.0       1.0
# 4            617.00                    20.0       1.0
# ...             ...                     ...       ...
# 881661       716.38                     8.0       0.0
# 881662       745.38                     2.0       0.0
# 881663       977.31                     9.0       0.0
# 881664       602.55                     2.0       0.0
# 881665       567.77                    21.0       0.0
#
# [881666 rows x 11 columns]

# %%
display(tabela["cancelou"].value_counts())# imprimie os valores  de cancelamento
display(tabela["cancelou"].value_counts(normalize=True).map("{:.1%}".format))#imprime em porcentagem dos valores
# Out:
# cancelou
# 1.0    499998
# 0.0    381666
# Name: count, dtype: int64
# cancelou
# 1.0    56.7%
# 0.0    43.3%
# Name: proportion, dtype: object

# %%
display(tabela["duracao_contrato"].value_counts(normalize=True)) #imprime as qtds de planos em forma decimal
display(tabela["duracao_contrato"].value_counts())##imprime as qtds de planos
# Out:
# duracao_contrato
# Annual       0.401963
# Quarterly    0.400448
# Monthly      0.197589
# Name: proportion, dtype: float64
# duracao_contrato
# Annual       354396
# Quarterly    353060
# Monthly      174207
# Name: count, dtype: int64

# %%
# analisando o contrato mensal
display(tabela.groupby("duracao_contrato").mean(numeric_only=True))
# descobrimos aqui que a média de cancelamentos é 1, ou seja, praticamente todos os contratos mensais cancelaram (ou todos)
# Out:
#                       idade  tempo_como_cliente  frequencia_uso  \
# duracao_contrato
# Annual            38.842188           31.446213       15.880213
# Monthly           41.552222           30.538632       15.499216
# Quarterly         38.830896           31.419838       15.886642
#
#                   ligacoes_callcenter  dias_atraso  total_gasto  \
# duracao_contrato
# Annual                       3.263395    12.465135   651.696325
# Monthly                      4.985661    15.007135   550.616445
# Quarterly                    3.265247    12.460891   651.426516
#
#                   meses_ultima_interacao  cancelou
# duracao_contrato
# Annual                         14.236120  0.460761
# Monthly                        15.478018  1.000000
# Quarterly                      14.234515  0.460256

# %%
# então descobrimos que contrato mensal é ruim, vamos tirar ele e continuar analisando
tabela = tabela[tabela["duracao_contrato"]!="Monthly"]
display(tabela)
display(tabela["cancelou"].value_counts())
display(tabela["cancelou"].value_counts(normalize=True).map("{:.1%}".format))
# Out:
#         idade    sexo  tempo_como_cliente  frequencia_uso  \
# 0        30.0  Female                39.0            14.0
# 2        55.0  Female                14.0             4.0
# 5        51.0    Male                33.0            25.0
# 6        58.0  Female                49.0            12.0
# 7        55.0  Female                37.0             8.0
# ...       ...     ...                 ...             ...
# 881661   42.0    Male                54.0            15.0
# 881662   25.0  Female                 8.0            13.0
# 881663   26.0    Male                35.0            27.0
# 881664   28.0    Male                55.0            14.0
# 881665   31.0    Male                48.0            20.0
#
#         ligacoes_callcenter  dias_atraso assinatura duracao_contrato  \
# 0                       5.0         18.0   Standard           Annual
# 2                       6.0         18.0      Basic        Quarterly
# 5                       9.0         26.0    Premium           Annual
# 6                       3.0         16.0   Standard        Quarterly
# 7                       4.0         15.0    Premium           Annual
# ...                     ...          ...        ...              ...
# 881661                  1.0          3.0    Premium           Annual
# 881662                  1.0         20.0    Premium           Annual
# 881663                  1.0          5.0   Standard        Quarterly
# 881664                  2.0          0.0   Standard        Quarterly
# 881665                  1.0         14.0    Premium        Quarterly
#
#         total_gasto  meses_ultima_interacao  cancelou
# 0            932.00                    17.0       1.0
# 2            185.00                     3.0       1.0
# 5            129.00                     8.0       1.0
# 6            821.00                    24.0       1.0
# 7            445.00                    30.0       1.0
# ...             ...                     ...       ...
# 881661       716.38                     8.0       0.0
# 881662       745.38                     2.0       0.0
# 881663       977.31                     9.0       0.0
# 881664       602.55                     2.0       0.0
# 881665       567.77                    21.0       0.0
#
# [707459 rows x 11 columns]
# cancelou
# 0.0    381666
# 1.0    325791
# Name: count, dtype: int64
# cancelou
# 0.0    53.9%
# 1.0    46.1%
# Name: proportion, dtype: object

# %%
# chegamos agora em menos da metade de pessoas cancelando, mas ainda temos muitas pessoas ai, vamos continuar analisando
display(tabela["assinatura"].value_counts(normalize=True))
display(tabela.groupby("assinatura").mean(numeric_only=True))
# vemos que assinatura é quase 1/3, 1/3, 1/3
# e que os cancelamentos são na média bem parecidos, então fica difícil tirar alguma conclusão da média, vamos precisar ir mais a fundo
# Out:
# assinatura
# Standard    0.339647
# Premium     0.338139
# Basic       0.322214
# Name: proportion, dtype: float64
#                 idade  tempo_como_cliente  frequencia_uso  \
# assinatura
# Basic       38.904813           32.316031       15.876921
# Premium     38.817869           30.977828       15.889632
# Standard    38.790478           31.048621       15.883393
#
#             ligacoes_callcenter  dias_atraso  total_gasto  \
# assinatura
# Basic                  3.310021    12.507054   648.642614
# Premium                3.235885    12.433483   653.338371
# Standard               3.249275    12.450690   652.566793
#
#             meses_ultima_interacao  cancelou
# assinatura
# Basic                    14.240814  0.475188
# Premium                  14.231170  0.452341
# Standard                 14.234280  0.454714

# %%
#instalr o plotly, pip install plotly
import plotly.express as px
for coluna in tabela.columns:
    grafico = px.histogram(tabela, x=coluna, color="cancelou")#imprime o grafico no eixo x dos contratos com cores diferentes de cancelamneto
    grafico.show()#imprime o grafico
#todos os contrados mensaes cancelam
#clentes qu atrasaram mais de dias cancelaram
#clientes que ligam mais de 4 vezes para o callcentes cancelam
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 5
#       3 for coluna in tabela.columns:
#       4     grafico = px.histogram(tabela, x=coluna, color="cancelou")#imprime o grafico no eixo x dos contratos com cores diferentes de cancelamneto
# ----> 5     grafico.show()#imprime o grafico
#       6 #todos os contrados mensaes cancelam
#       7 #clentes qu atrasaram mais de dias cancelaram
#       8 #clientes que ligam mais de 4 vezes para o callcentes cancelam
#
# File c:\Users\davih\AppData\Local\Programs\Python\Python311\Lib\site-packages\plotly\basedatatypes.py:3410, in BaseFigure.show(self, *args, **kwargs)
#    3377 """
#    3378 Show a figure using either the default renderer(s) or the renderer(s)
#    3379 specified by the renderer argument
#    (...)
#    3406 None
#    3407 """
#    3408 import plotly.io as pio
# -> 3410 return pio.show(self, *args, **kwargs)
#
# File c:\Users\davih\AppData\Local\Programs\Python\Python311\Lib\site-packages\plotly\io\_renderers.py:394, in show(fig, renderer, validate, **kwargs)
#     389         raise ValueError(
#     390             "Mime type rendering requires ipython but it is not installed"
#     391         )
#     393     if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 394         raise ValueError(
#     395             "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     396         )
#     398     ipython_display.display(bundle, raw=True)
#     400 # external renderers
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed

# %%
# com os graficos a gente consegue descobrir muita coisa:
# dias atraso acima de 20 dias, 100% cancela
# ligações call center acima de 5 todo mundo cancela

tabela = tabela[tabela["ligacoes_callcenter"]<5]
tabela = tabela[tabela["dias_atraso"]<=20]
display(tabela)
display(tabela["cancelou"].value_counts())
display(tabela["cancelou"].value_counts(normalize=True).map("{:.1%}".format))

# se resolvermos isso, já caímos para 18% de cancelamento
# é claro que 100% é utópico, mas com isso já temos as principais causas (ou talvez 3 das principais):
# - forma de contrato mensal
# - necessidade de ligações no call center
# - atraso no pagamento
# Out:
#         idade    sexo  tempo_como_cliente  frequencia_uso  \
# 6        58.0  Female                49.0            12.0
# 7        55.0  Female                37.0             8.0
# 9        64.0  Female                 3.0            25.0
# 13       48.0  Female                35.0            25.0
# 17       47.0    Male                41.0             NaN
# ...       ...     ...                 ...             ...
# 881661   42.0    Male                54.0            15.0
# 881662   25.0  Female                 8.0            13.0
# 881663   26.0    Male                35.0            27.0
# 881664   28.0    Male                55.0            14.0
# 881665   31.0    Male                48.0            20.0
#
#         ligacoes_callcenter  dias_atraso assinatura duracao_contrato  \
# 6                       3.0         16.0   Standard        Quarterly
# 7                       4.0         15.0    Premium           Annual
# 9                       2.0         11.0   Standard        Quarterly
# 13                      1.0         13.0      Basic           Annual
# 17                      1.0          5.0        NaN           Annual
# ...                     ...          ...        ...              ...
# 881661                  1.0          3.0    Premium           Annual
# 881662                  1.0         20.0    Premium           Annual
# 881663                  1.0          5.0   Standard        Quarterly
# 881664                  2.0          0.0   Standard        Quarterly
# 881665                  1.0         14.0    Premium        Quarterly
#
#         total_gasto  meses_ultima_interacao  cancelou
# 6            821.00                    24.0       1.0
# 7            445.00                    30.0       1.0
# 9            415.00                    29.0       1.0
# 13           518.00                    17.0       1.0
# 17           151.00                    19.0       1.0
# ...             ...                     ...       ...
# 881661       716.38                     8.0       0.0
# 881662       745.38                     2.0       0.0
# 881663       977.31                     9.0       0.0
# 881664       602.55                     2.0       0.0
# 881665       567.77                    21.0       0.0
#
# [464480 rows x 11 columns]
# cancelou
# 0.0    379032
# 1.0     85448
# Name: count, dtype: int64
# cancelou
# 0.0    81.6%
# 1.0    18.4%
# Name: proportion, dtype: object
